# %%
from sklearn.datasets import load_iris
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import json

# %%
data = load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target

# %%
df.to_csv('iris_data.csv', index=False)
# Out:
# To track the changes with git, run:
#
# 	git add iris_data.csv.dvc .gitignore
#
# To enable auto staging, run:
#
# 	dvc config core.autostage true
# \u280b Checking graph
# [master (root-commit) de1c4af] feat: add ds data
#  6 files changed, 49 insertions(+)
#  create mode 100644 .dvc/.gitignore
#  create mode 100644 .dvc/config
#  create mode 100644 .dvcignore
#  create mode 100644 .gitignore
#  create mode 100644 iris_data.csv.dvc
#  create mode 100644 iris_ds.ipynb

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['target']), df['target'], test_size=0.3)

# %%
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.9555555555555556

# %%
import joblib
joblib.dump(model, 'random_forest_model.pkl')
# Out:
# ['random_forest_model.pkl']
